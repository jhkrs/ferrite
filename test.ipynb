# %%
from ferrite import sign_transaction
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ferrite import sign_transaction
#
# File c:\Users\josep\Documents\Development\Crypto\ferrite\ferrite\__init__.py:2
#       1 import sys
# ----> 2 from .account import ferrite_account, sign_transaction
#       4 def patch_web3():
#       5     if "web3" in sys.modules:
#
# File c:\Users\josep\Documents\Development\Crypto\ferrite\ferrite\account.py:4
#       1 from eth_account.datastructures import SignedTransaction
#       2 from hexbytes import HexBytes
# ----> 4 from . import _ferrite_core
#       6 def sign_transaction(transaction_dict: dict, private_key: str) -> SignedTransaction:
#       7     signed_tx_dict = _ferrite_core.sign_transaction(transaction_dict, private_key)
#
# ...
